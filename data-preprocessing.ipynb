# %%
import requests
import pandas as pd
import json
from openpyxl import Workbook
from utils import get_number_of_jobs_T, get_number_of_jobs_L

# %%
# Configuration
api_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json"

# %%
# Number of jobs requiring Python
get_number_of_jobs_T(api_url, "Python")
# Out:
# ('Python', 1173)

# %%
# Number of jobs located in Los Angeles
get_number_of_jobs_L(api_url, "Los Angeles")

# %%
technologies = ["C", "C#", "C++","Java","JavaScript","Python","Scala","Oracle","SQL Server","mysql","PostgreSQL","MongoDB"]

# %%
wb = Workbook()
ws = wb.active

ws.append["Technology", "Number of Jobs"]
for technology in technologies:
    tech, num = get_number_of_jobs_T(api_url, technology)
    ws.append([tech, num])

wb.save("job-postings.xlsx")
